# %%
class payment:
    def pay(self, amount):
        pass

class upi(payment):
    def pay(self, amount):
        print("paid using upi",amount)

class card(payment):
    def pay(self, amount):
        print("paid using card",amount)

obj=upi()
print(obj.pay(30))
# Out:
# paid using upi 30
# None
