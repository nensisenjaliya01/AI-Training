# %%
def greet_people(**kwargs):
    for key, name in kwargs.items():
        print(f"hello,<name>!")
greet_people(nensi="nensi")
# Out:
# hello,<name>!

# %%
def sum(**kwargs):
    total = 0
    for key, values in kwargs.items():
        if isinstance(values, (int, float)):
            total += values
    return total
result = sum(a=1, b=2, c=5.5)
print(result)
# Out:
# 8.5

# %%
def employee_info(emp_id, **kwargs):
    print(f"Hello!! :", empid)

    for key, values in kwargs.items():
        print(f"{key} : {values}")
result = employee_info(11, name ="nensi", salary=25000, age=20)
print(result)

# def employee_info(emp_id, **kwargs):
#     print("Employee ID:", emp_id)
#     for key, value in kwargs.items():
#         print(key, ":", value)

# # Call function correctly
# employee_info(11, name="nensi", salary=25000, age=20)
# Out:
# Hello!! : 11
# name : nensi
# salary : 25000
# age : 20
# None

# %%
b = 7
def add():
    a=4
    d=6
    print(a+d)

add()

def mul():
    e = 9
    print(b*e)

mul()
# Out:
# 10
# 63

# %%
def div(f,g=2):
    print(f/g)

div(6)
# Out:
# 3.0

# %%
list = []
def list(*a):
    List.append(a)
    print(List)

list(1,2,3,4,6,77)
print(type(List))
# Out:
# [(1, 2, 3, 4, 6, 77), (1, 2, 3, 4, 6, 77)]
# <class 'list'>

# %%
def geet(name, age=20):
    print(f"Hello {name}, you are {age} years old.")
geet("nensi")
geet("ruhu",18)
# Out:
# Hello nensi, you are 20 years old.
# Hello ruhu, you are 18 years old.
