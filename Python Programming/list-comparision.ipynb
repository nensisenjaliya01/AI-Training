# %%
l1 = [1, 2, 3]
l2 = [1, 4, 3]

if l1 == l2:
    print("both are same")
else:
    print("not same")
# Out:
# not same

# %%
l1 = []
l2 = [1]
if not l1 and l2:
    print("l1 is empty and list2 is not")
else:
    print("condtion is not satisfied")
# Out:
# l1 is empty and list2 is not

# %%
a = [1, 3, 4]
b = [1, 4, 4]
if a[0] == b[0] and a[2] == b[2]:
    print("both element is same")
else:
    print("both are not same")
# Out:
# both element is same

# %%
a = [1, 3, 4]
b = [2, 6, 4]
common = []
for i in a:
    if i in b:
        common.append(i)
print(i)
# Out:
# 4

# %%
a = [1, 3, 4]
b = [2, 3, 4]
common = []
if set(a).issubset(set(b)):
    print("all the elemts of a is there in b")
