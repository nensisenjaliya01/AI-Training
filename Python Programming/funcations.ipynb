# %%
def name():
    return "hello"

# %%
def print_name(name):
    print("hello", name)
print_name("nensi")
# Out:
# hello nensi

# %%
def sum(a, b):
    return a+b
print(sum(2, 2))
# Out:
# 4

# %%
def squre(a):
    return a**2
print(squre(4))
# Out:
# 16

# %%
def largest_num(a, b, c):
    if a >= b and a>=c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c
    print(largest_num(2, 4, 6))

# %%
def sum_list(num):
    total = 0
    for n in num:
        total += n
    return total
print(sum_list([1, 2, 3, 4]))
# Out:
# 10

# %%
def prime_num(n):

    if n <= 1:
        print("not prime")
        return
    for i in range(2, n):
        if n % i == 0:
            print("not prime")
            return
        
    print("prime")
    
number = int(input("Enter number:"))
print(prime_num(number))
# Out:
# prime
# None

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
number = int(input("Enter number:"))
print(factorial(number))
# Out:
# 2

# %%
def calculator(a, b, operation):
    if operation == "add":
        return a + b
    elif operation == "subtract":
        return a - b
    elif operation == "multiply":
        return a * b
    elif operation == "divide":
        return a / b
    else:
        return "invalid number"
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
operation = input("Enter operation (add, subtract, multiply, divide):")
print(calculator(a, b, operation))
# Out:
# 4

# %%
#default arguments:
def greet(name, msg = "good morningg"):
    print("hello", name + "," +msg)
greet("nensi")
greet("nensi", "how are you?")
# Out:
# hello nensi,good morningg
# hello nensi,how are you?

# %%
#lemda funcation:
add = lambda a, b : a + b
print(add(2, 2))
# Out:
# 4
