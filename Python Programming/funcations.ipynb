# %%
def name():
    return "hello"

# %%
def print_name(name):
    print("hello", name)
print_name("nensi")
# Out:
# hello nensi

# %%
def sum(a, b):
    return a+b
print(sum(2, 2))
# Out:
# 4

# %%
def squre(a):
    return a**2
print(squre(4))
# Out:
# 16

# %%
def largest_num(a, b, c):
    if a >= b and a>=c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c
    print(largest_num(2, 4, 6))
